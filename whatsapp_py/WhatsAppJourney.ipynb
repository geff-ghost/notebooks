# %% [markdown]
# # WhatsApp Data Analysis and AI journey

# %% [markdown]
# ## What is Numpy?
# - Numpy Numerical Python is a powerful Python library used for working with numbers and arrays.
#
# ## Why Use Numpy?
# - Python lists work well, but Numpy arrays are much faster for mathematical operations
# - Numpy is used for:
# 1. Data Analysis
# 2. Machine Learning
# 3. Data Visualization
# 4. Scientific Computing

# %%
# Importing the library
import numpy as np

# %%
# Creating numpy arrays
numbers = np.array([10, 20, 30, 40])
print(numbers)
# Out:
# [10 20 30 40]

# %%
# Check Array Properties
print(numbers.ndim) # Number of dimentions
print(numbers.size) # Total number of elements
print(numbers.shape) # Structure of the array
# Out:
# 1
# 4
# (4,)

# %%
# Accessing Array Elements
print(numbers[0])
print(numbers[2])
# Out:
# 10
# 30

# %%
# Array Slicing
print(numbers[1:4])
# Out:
# [20 30 40]

# %%
# Basic Array Operations
print(numbers + 5)
print(numbers * 2)
# Out:
# [15 25 35 45]
# [20 40 60 80]

# %% [markdown]
# - Numpy performs operations on every element at once (elementwise operation)

# %%
# Print the first and last element
print(numbers[-1])
print(numbers[0])

# Add 100 to every element
print(numbers + 100)
# Out:
# 40
# 10
# [110 120 130 140]

# %% [markdown]
# ## Master 2D Arrays, Reshaping & Mathematical Functions
#
# ### What is a 2D Array?
# - A 2D array stores data in rows and columns, just like a table or spreadsheet

# %%
import numpy as np

matrix = np.array([
    [10, 20, 30],
    [40, 50, 60]
])

print(matrix)
# Out:
# [[10 20 30]
#  [40 50 60]]

# %%
# Check Array Shape
# Use the .shape attribute to find the dimensions of an array

print(matrix.shape) # 2 row and 3 columns
# Out:
# (2, 3)

# %%
# Reshape an Array
# Convert a 1D array into a 2D array using .reshape()
numbers = np.array([1, 2, 3, 4, 5, 6])

new_array = numbers.reshape(2, 3)
print(new_array)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %% [markdown]
# - The total number of elements must remain the same
#
# ## Mathematical Functions
# - NumPy provides built-in functions for calculations

# %%
numbers = np.array([10, 20, 30, 40])

print(np.sum(numbers))
print(np.mean(numbers))
# Out:
# 100
# 25.0

# %%
# Minimum and Maximum Values
numbers = np.array([25, 10, 45, 30])

print(np.min(numbers))
print(np.max(numbers))
# Out:
# 10
# 45

# %%
# Mean, Median & Standard Deviation
# These are common statistical calculations
numbers = np.array([10, 20, 30, 40])

print(np.mean(numbers)) # Average value
print(np.median(numbers)) # Middle value after sorting
print(np.std(numbers)) # Measures how spread out the values are
# Out:
# 25.0
# 25.0
# 11.180339887498949

# %%
matrix.size
# Out:
# 6

# %% [markdown]
# ## Indexing, Slicing, Boolean Indexing and Filtering
# - One of the biggest advantages of NumPy is how quickly you can access and filter data.
#
# ### Array Indexing
# - Indexing is used to access a specific element in an array.

# %%
import numpy as np
numbers = np.array([10, 20, 30, 40, 50, 60])

# Indexing starts from 0
print(numbers[0])
print(numbers[3])
# Out:
# 10
# 40

# %% [markdown]
# ### Array Slicing
# - Slicing extracts a portion of an array

# %%
print(numbers[1:5])
print(numbers[:3])
print(numbers[3:])
print(numbers[-2:])
# Out:
# [20 30 40 50]
# [10 20 30]
# [40 50 60]
# [50 60]

# %% [markdown]
# ### Indexing in 2D Arrays
# - Access elements using row and column indexes.

# %%
matrix = np.array([
    [10, 20, 30],
    [40, 50, 60],
    [70, 80, 90]
])

print(matrix[1, 2])
# Out:
# 60

# %%
# Access an entire row:
print(matrix[0])

# Access an entire column
print(matrix[:, 1])
# Out:
# [10 20 30]
# [20 50 80]

# %% [markdown]
# ### Boolean Indexing
# - Boolean indexing selects elements that satisfy a condition.

# %%
numbers = np.array([12, 25, 8, 40, 15])
print(numbers > 20)
# Out:
# [False  True False  True False]

# %% [markdown]
# ### Filtering Data
# - Use Boolean indexing to filter values.

# %%
print(numbers[numbers > 20])
# Out:
# [25 40]

# %%
print(numbers[numbers % 2 == 0])
# Out:
# [12  8 40]

# %% [markdown]
# ### Multiple Conditions
# - Filter using more than one condition.

# %%
numbers = np.array([12, 25, 8, 40, 15, 30])
result = numbers[(numbers >= 15) & (numbers <= 30)]
print(result)
# Out:
# [25 15 30]

# %% [markdown]
# ## Sorting, Searching, Stacking & Spliting Arrays
#
# ### Sorting Arrays
# - Numpy provides the **sort()** functions to sort array elements in ascending order.

# %%
import numpy as np

numbers = np.array([40, 10, 30, 20])

print(np.sort(numbers))
# Out:
# [10 20 30 40]

# %% [markdown]
# ### Searching Elements
# - Use **where()** to find the index of an element.

# %%
numbers = np.array([10, 20, 30, 20, 40])

print(np.where(numbers == 20))
# Out:
# (array([1, 3]),)

# %% [markdown]
# This means the value 20 is present at index 1 and 3.
#
# ### Stacking Arrays Vertically
# - Combine arrays column-wise using **vstack()**.

# %%
array1 = np.array([1, 2, 3])
array2 = np.array([4, 5, 6])

# combines two arrays row-wise
print(np.vstack((array1, array2)))
# Out:
# [[1 2 3]
#  [4 5 6]]

# %% [markdown]
# ### Stacking Arrays Horizontally
# - Combine arrays column-wise using **hstack()**.

# %%
array1 = np.array([1, 2, 3])
array2 = np.array([4, 5, 6])

print(np.hstack((array1, array2)))
# Out:
# [1 2 3 4 5 6]

# %% [markdown]
# ### Splitting Arrays
# - Use **split()** to divide an array into equal parts.

# %%
numbers = np.array([10, 20, 30, 40, 50, 60])

print(np.split(numbers, 3))
# Out:
# [array([10, 20]), array([30, 40]), array([50, 60])]

# %% [markdown]
# ### Copy vs View
# #### Copy
# - Changes to the original array do not affect the copied array.

# %%
numbers = np.array([10, 20, 30])

copy_array = numbers.copy()

numbers[0] = 100

print(copy_array)
print(numbers)
# Out:
# [10 20 30]
# [100  20  30]

# %% [markdown]
# #### View
# - A view shares the same data as the original array.

# %%
numbers = np.array([10, 20, 30])

view_array = numbers.view()

numbers[0] = 100
print(view_array)
# Out:
# [100  20  30]

# %% [markdown]
# ### Find Unique Values
# - Use **unique()** to remove duplicate values.

# %%
numbers = np.array([10, 20, 20, 30, 30, 40])
print(np.unique(numbers))
# Out:
# [10 20 30 40]

# %%
# Find Index of a specific value
print(np.where(numbers == 20))
# Out:
# (array([1, 2]),)

# %% [markdown]
# ## Random Numbers, Matrix Operations & Saving Arrays
# ### Random Number Generation
# - NumPy provides the 'random' module to generate random values

# %%
import numpy as np
number = np.random.randint(1, 101)
print(number)
# Out:
# 19

# %%
# Generate Multiple Random Numbers
numbers = np.random.randint(1, 11, size=5)
print(numbers)
# Out:
# [ 1  6  7 10  2]

# %% [markdown]
# ### Create a Matrix
# - A matrix is a two-dimensional NumPy array.

# %%
matrix = np.array([
    [1, 2],
    [3, 4]
])
print(matrix)
print('This is a {} matrix'.format(matrix.shape))
# Out:
# [[1 2]
#  [3 4]]
# This is a (2, 2) matrix

# %% [markdown]
# ### Transpose of a Matrix
# - Transpose swaps rows and columns.

# %%
print(matrix)
print()
print(matrix.T)
# Out:
# [[1 2]
#  [3 4]]
#
# [[1 3]
#  [2 4]]

# %% [markdown]
# ### Matrix Multiplication
# - Use the "@" operator or "np.matmul()".

# %%
matrix1 = np.array([
    [1, 2],
    [3, 4]
])
matrix2 = np.array([
    [5, 6],
    [7, 8]
])
print(matrix1 @ matrix2)
# Out:
# [[19 22]
#  [43 50]]

# %% [markdown]
# ### Save an Array
# - Save a NumPy array to a file using 'save()'.

# %%
numbers = np.array([10, 20, 30, 40])
np.save('numbers.npy', numbers)

# %% [markdown]
# ### Load an Array
# - Read a saved array using 'load()'

# %%
numbers = np.load('numbers.npy')
print(numbers)
# Out:
# [10 20 30 40]

# %% [markdown]
# ### Why Use NumPy?
# - Fast numerical computations
# - Efficient memory usage
# - Easy array manipulation
# - Built-in mathematical functions
# - Foundation for Pandas, SciPy, Scikit-learn, TensorFlow and many other libraries.

# %% [markdown]
# # File Handling & Exception Handling
# Real-world applications need to store and manage data. That's where file handling becomes important.
#
# ## What is File Handling?
#
# - File handling allows Python to:
# 1. Read data from files
# 2. Write data into files
# 3. Store information permenently
#
# ## Opening a File
# Use **open()** to work with files.
#
# > Example:
# file = open('data.txt', 'r')
#
# - **'r'** means read mode
#
# ## Reading a File

# %%
file = open('data.txt', 'r')
content = file.read()
print(content)
file.close()
# Out:
# Hello! This is an example text for this file.
#
# More lines added to this file.
#
# These make the file longer and easier to work with.

# %% [markdown]
# ## Read Line by Line

# %%
file = open('data.txt', 'r')
for line in file:
    print(line)
file.close()
# Out:
# Hello! This is an example text for this file.
#
#
#
# More lines added to this file.
#
#
#
# These make the file longer and easier to work with.

# %% [markdown]
# ## Writing to a File
# - Use **'w'** mode to write data.

# %%
file = open('notes.txt', 'w')
file.write('Python File Handling')
file.close() # 'w' overwrites existing data

# %% [markdown]
# ## Appending Data
# - Use **'a'** mode to add data without deleting old content

# %%
file = open('notes.txt', 'a')
file.write('\nNew Line Added')
file.close()

# %% [markdown]
# ## Using **with** Statement
# Best way to handle files
# 1. Automatically closes the file
# 2. Cleaner and safer code

# %%
with open('data.txt', 'r') as file:
    content = file.read()
    print(content)
# Out:
# Hello! This is an example text for this file.
#
# More lines added to this file.
#
# These make the file longer and easier to work with.

# %% [markdown]
# ## Working with CSV Files and Exception Handling
# - CSV files are used for tabular data.
#
# ### What is Exception Handling?
# - Errors can crash programs.
# - Exception handling prevents that

# %%
import csv
try:
    with open('data.csv', 'r') as file:
        reader = csv.reader(file)
        for row in reader:
            print(row)
except:
    print('File does not exist!!!')
# Out:
# File does not exist!!!

# %%
# Handling Specific Errors
try:
    result = 10 / 0
except ZeroDivisionError:
    print('Cannot divide by zero')
# Out:
# Cannot divide by zero

# %% [markdown]
# ## Finally Block
# - **finally** always runs whether error occurs or not.

# %%
try:
    print('Start')
except:
    print('Error')
finally:
    print('Finished')
# Out:
# Start
# Finished

# %% [markdown]
# # Object-Orientend Programming (OOP)
# - Object-Oriented Programming (OOP) in one of the most important concepts in Python.
# - Almost every real world Python application uses OOP concepts.
#
# ## What is OOP?
# - OOP is a programming approach that organizes code into objects
#
# **Each object has:**
# - Properties (Data)
# - Behavior (Fuctions)
#
# ## What is a Class?
# - A class is a blueprint for creating objects
#
# **Example:**
# class Car:
#
# - Here, 'Car' is a class
#
# ## Creating an Object
# - An object is an instance of a class:

# %%
class Car:
    pass

car1 = Car()
print(type(car1))
# Out:
# <class '__main__.Car'>

# %% [markdown]
# ## Attributes in a Class
# - Attributes store information

# %%
class Car:
    brand = 'Toyota'

car1 = Car()
print(car1.brand)
# Out:
# Toyota

# %% [markdown]
# ## Constructor ('init')
# - A constructor runs automatically when an object is created.

# %%
class Car:
    def __init__(self, brand):
        self.brand = brand

car1 = Car('Toyota')
print(car1.brand)
# Out:
# Toyota

# %% [markdown]
# ## Instance Methods
# - Methods define object behavior

# %%
class Car:
    def start(self):
        print('Car Started')

car1 = Car()
car1.start()
# Out:
# Car Started

# %% [markdown]
# ## Inheritance
# - Inheritance allows one class to use features of another class.

# %%
class Vehicle:
    def moves(self):
        print('Vehicle Moving')

class Car(Vehicle):
    pass

car1 = Car()
car1.moves()
# Out:
# Vehicle Moving

# %% [markdown]
# ## Encapsulation
# - Encapsulation hides data from direct access.

# %%
class Account:
    def __init__(self):
        self.__balance = 1000 # private variable

account = Account()

# %% [markdown]
# ## Polymorphism
# - Same method name, different behavior.

# %%
class Bird:
    def sound(self):
        print('Bird Sound')

class Dog:
    def sound(self):
        print('Dog Sound')

bird = Bird()
dog = Dog()

bird.sound()
dog.sound()
# Out:
# Bird Sound
# Dog Sound

# %% [markdown]
# ## Method Overriding
# - Child class can redefine a parent method.

# %%
class Vehicle:
    def moves(self):
        print('Vehicle Moving')

class Bike(Vehicle):
    def moves(self):
        print('Bike Moving')

bike = Bike()
bike.moves()
# Out:
# Bike Moving

# %% [markdown]
# # What is an API?
# - API stands fro Application Programming Interface.
# - An API allows different applications to communicate with each other.
#
# **Examples**
# 1. Weather Apps
# 2. Payment Gateways
# 3. Mobile Applications
# 4. AI Applications
#
# ## Working with APIs
# - The most popular library for API requests is 'requests'.

# %%
import requests

# response = requests.get('https://api.example.com/data')

# print(response.status_code)

# %% [markdown]
# - 200 means the request was successful
#
# ## Understanding JSON Data
# - Most API return data in JSON format
#
# **Example JSON:**
# {
#     'product': 'Laptop',
#     'price': 50000,
#     'available': true
# }

# %%
# Convert JSON into Python'
data = response.json()
print(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Convert JSON into Python'
# ----> 2 data = response.json()
#       3 print(data)
#
# NameError: name 'response' is not defined

# %% [markdown]
# ## What is Web Scraping?
# - Web Scraping mean extractind data from websites automatically
#
# **Used for:**
# 1. Price Tracking
# 2. News Collection
# 3. Job Listings
# 4. Research Projects
#
# **Popular Libraries:** BeautifulSoup, requests
#
# ## Simple Web Scraping Example

# %%
import requests
from bs4 import BeautifulSoup
page = requests.get('https://example.com')
soup = BeautifulSoup(page.text, 'html.parser')
print(soup.title.text)
# This extract the webpage title.

# %% [markdown]
# ## Important Note About Web Scraping
# - Always:
# 1. Read website policies
# 2. Respect rate limits
# 3. Avoid excessive requests
# 4. Use scraping responsibly
# - Some websites prohibit automated scraping

# %% [markdown]
# # Pandas
#
# ## What is Pandas?
# - Pandas is an open-source Python library used for:
# 1. Data Analysis
# 2. Data Cleaning
# 3. Data Transformation
# 4. Data Exploration
# 5. Working with Excel and CSV files
# - It helps you organize and analyze structured data efficiently
#
# ## What is a Series?
# - A Series is a one-demensional data structure

# %%
import pandas as pd
numbers = pd.Series([10, 20, 30, 40])

print(numbers)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %% [markdown]
# ## What is a DataFrame?
# - A DataFrame is a table with rows and columns

# %%
data = {
    'Product': ['Laptop', 'Mobile', 'Tablet'],
    'Price': [50000, 25000, 18000]
}

df = pd.DataFrame(data)

print(df)
# Out:
#   Product  Price
# 0  Laptop  50000
# 1  Mobile  25000
# 2  Tablet  18000

# %% [markdown]
# ## Read a CSV File
# - Use read_csv() to load CSV files.

# %%
df = pd.read_csv('sales.csv')
print(df)
# Out:
#   Product  Sales
# 0       A    100
# 1       B    150
# 2       C    200
# 3       A    120
# 4       B    180
# 5       C    220

# %% [markdown]
# - Pandas automatically converts the CSV into a DataFrame.
#
# ## View Data

# %%
# Display the first five rows
print(df.head())

# Display the last five rows
print(df.tail())

# Check the size of the dataset
print(df.shape)

# Display column names
print(df.columns)
# Out:
#   Product  Sales
# 0       A    100
# 1       B    150
# 2       C    200
# 3       A    120
# 4       B    180
#   Product  Sales
# 1       B    150
# 2       C    200
# 3       A    120
# 4       B    180
# 5       C    220
# (6, 2)
# Index(['Product', 'Sales'], dtype='str')

# %% [markdown]
# # Selecting Data, Rows & Columns with Examples
# - Selecting the right data is one of the most frequently used skills in Pandas.
#
# ## Create a Sample DataFrame
# - We'll use this DataFrame throughout the examples.

# %%
import pandas as pd

data = {
    'Product': ['Laptop', 'Mobile', 'Tablet', 'Monitor'],
    'Price': [50000, 25000, 18000, 12000],
    'Stock': [10, 25, 15, 8]
}

df = pd.DataFrame(data)

print(df)
# Out:
#    Product  Price  Stock
# 0   Laptop  50000     10
# 1   Mobile  25000     25
# 2   Tablet  18000     15
# 3  Monitor  12000      8

# %% [markdown]
# ## Select a Single Column
# - Use the column name to access one column

# %%
print(df['Product'])
# Out:
# 0     Laptop
# 1     Mobile
# 2     Tablet
# 3    Monitor
# Name: Product, dtype: str

# %% [markdown]
# ## Select Multiple Columns
# - Pass a list of column names.

# %%
print(df[['Product', 'Price']])
# Out:
#    Product  Price
# 0   Laptop  50000
# 1   Mobile  25000
# 2   Tablet  18000
# 3  Monitor  12000

# %% [markdown]
# ## Select Rows using **loc[]**
# - **loc[]** selects rows using labels (index values)

# %%
print(df.loc[2])
# Out:
# Product    Tablet
# Price       18000
# Stock          15
# Name: 2, dtype: object

# %% [markdown]
# ## Select Rows using **iloc[]**
# - **iloc[]** selects rows using their position.

# %%
print(df.iloc[1:3])
# Out:
#   Product  Price  Stock
# 1  Mobile  25000     25
# 2  Tablet  18000     15

# %% [markdown]
# ## Filter Data
# - Display only products with a price greater than 20,000

# %%
print(df[df['Price'] > 20000])
# Out:
#   Product  Price  Stock
# 0  Laptop  50000     10
# 1  Mobile  25000     25

# %% [markdown]
# ## Sort Data

# %%
# Sort products by price in ascending order
print(df.sort_values('Price'))
# Out:
#    Product  Price  Stock
# 3  Monitor  12000      8
# 2   Tablet  18000     15
# 1   Mobile  25000     25
# 0   Laptop  50000     10

# %%
# Sort in descending order
print(df.sort_values('Price', ascending=False))
# Out:
#    Product  Price  Stock
# 0   Laptop  50000     10
# 1   Mobile  25000     25
# 2   Tablet  18000     15
# 3  Monitor  12000      8

# %% [markdown]
# # Data Cleaning, Missing Values & Duplicates
# - Real-world datasets are rarely perfect.
# - Before analyzing data, you need to clean in. Data cleaning is one of the most important tasks for every Data Analyst and Data Scientist.
#
# ## What are Missing Values?
# - Missing values occur when some data is unavailable.

# %%
import pandas as pd

data = {
    'Product': ['Laptop','Mobile', None, 'Tablet'],
    'Price': [50000, None, 18000, 15000]
}

df = pd.DataFrame(data)

print(df)
# Out:
#   Product    Price
# 0  Laptop  50000.0
# 1  Mobile      NaN
# 2     NaN  18000.0
# 3  Tablet  15000.0

# %% [markdown]
# - 'NaN' means Not a Number, indicating a missing value
#
# ## Detect Missing Values
# - Use **isnull()** to identify missing values.

# %%
print(df.isnull())
# Out:
#    Product  Price
# 0    False  False
# 1    False   True
# 2     True  False
# 3    False  False

# %%
# Count missing values in each column
print(df.isnull().sum())
# Out:
# Product    1
# Price      1
# dtype: int64

# %% [markdown]
# ## Remove Missing Values
# - Use **dropna()** to remove rows with missing values.

# %%
clean_df = df.dropna()
print(clean_df)
# Out:
#   Product    Price
# 0  Laptop  50000.0
# 3  Tablet  15000.0

# %% [markdown]
# ## Fill Missing Values
# - Instead of deleting rows, you can replace missing values.

# %%
# Replace missing prices with 0
df['Price'] = df['Price'].fillna(0)

# Replace missing product names
df['Product'] = df['Product'].fillna('Unknown')

print(df)
# Out:
#    Product    Price
# 0   Laptop  50000.0
# 1   Mobile      0.0
# 2  Unknown  18000.0
# 3   Tablet  15000.0

# %% [markdown]
# ## Find Duplicate Rows
# - Use **duplicate()** to identify duplicat records.

# %%
print(df.duplicated())
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# dtype: bool

# %% [markdown]
# - If a row is repeated, it wil return **True**
#
# ## Remove Duplicate Rows
# - Use **drop_duplicates()**

# %%
df = df.drop_duplicates()
print(df)
# Out:
#    Product    Price
# 0   Laptop  50000.0
# 1   Mobile      0.0
# 2  Unknown  18000.0
# 3   Tablet  15000.0

# %% [markdown]
# - This keeps only unique records
#
# ## Check Data Information
# - Use **info()** to understand your dataset.

# %%
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Product  4 non-null      str
#  1   Price    4 non-null      float64
# dtypes: float64(1), str(1)
# memory usage: 196.0 bytes
# None

# %% [markdown]
# ## Generate Summary Statistics
# - Use **describe()** to get statistical information.

# %%
print(df.describe())
# Out:
#               Price
# count      4.000000
# mean   20750.000000
# std    21029.740845
# min        0.000000
# 25%    11250.000000
# 50%    16500.000000
# 75%    26000.000000
# max    50000.000000

# %% [markdown]
# **Pro Tip**
# - A good data analyst always follows this order:
# 1. Load the dataset
# 2. Check **head()**
# 3. Check **info()**
# 4. Find missing values
# 5. Remove duplicates
# 6. Start the analysis

# %% [markdown]
# # GroupBy, Aggregation & Data Analysis
# - One of the biggest strengths of Pandas is its ability to summarize large datasets with just a few lines of code.
#
# ## Create a Sample DataFrame
# - We'll use this dataset throughout the examples

# %%
import pandas as pd

data = {
    'Department': ['Sales', 'IT', 'Sales', 'HR', 'IT', 'HR'],
    'Salary': [50000, 70000, 55000, 45000, 75000, 48000],
    'Experience': [2, 5, 3, 1, 6, 2]
}

df = pd.DataFrame(data)
print(df)
# Out:
#   Department  Salary  Experience
# 0      Sales   50000           2
# 1         IT   70000           5
# 2      Sales   55000           3
# 3         HR   45000           1
# 4         IT   75000           6
# 5         HR   48000           2

# %% [markdown]
# ## What is GroupBy?
# - **groupby()** groups rows having the same value.

# %%
print(df.groupby('Department'))

# %% [markdown]
# - This creates groups based on the Department column.
#
# ## Calculate Average Salary
# - Find the average salary for each department

# %%
print(df.groupby('Department')['Salary'].mean())
# Out:
# Department
# HR       46500.0
# IT       72500.0
# Sales    52500.0
# Name: Salary, dtype: float64

# %% [markdown]
# ## Calculate Average Salary
# - Find the average salary for each department

# %%
print(df.groupby('Department')['Salary'].sum())
# Out:
# Department
# HR        93000
# IT       145000
# Sales    105000
# Name: Salary, dtype: int64

# %% [markdown]
# ## Multiple Aggregation Functions
# - Calculate multiple statistics at once.

# %%
print(
    df.groupby('Department')['Salary'].agg(['sum','mean', 'max','min', 'std'])
)
# Out:
#                sum     mean    max    min          std
# Department
# HR           93000  46500.0  48000  45000  2121.320344
# IT          145000  72500.0  75000  70000  3535.533906
# Sales       105000  52500.0  55000  50000  3535.533906

# %% [markdown]
# ## Count Records
# - Count the number of records in each department

# %%
print(df.groupby('Department').size())
# Out:
# Department
# HR       2
# IT       2
# Sales    2
# dtype: int64

# %% [markdown]
# ## Count Unique Values
# - Use **value_counts()** to count occurrences.

# %%
print(df['Department'].value_counts())
# Out:
# Department
# Sales    2
# IT       2
# HR       2
# Name: count, dtype: int64

# %% [markdown]
# ## Find Unique Values
# - Display unique department names.

# %%
print(df['Department'].unique())
# Out:
# <StringArray>
# ['Sales', 'IT', 'HR']
# Length: 3, dtype: str

# %% [markdown]
# ## Sort Aggregated Results
# - Sort departments by average salary.

# %%
result = df.groupby('Department')['Salary'].mean()
print(result.sort_values(ascending=False))
# Out:
# Department
# IT       72500.0
# Sales    52500.0
# HR       46500.0
# Name: Salary, dtype: float64

# %% [markdown]
# ## Practice Exercises

# %%
# Find the average salary for each department
print(df.groupby('Department')['Salary'].mean())
# Out:
# Department
# HR       46500.0
# IT       72500.0
# Sales    52500.0
# Name: Salary, dtype: float64

# %%
# Find the highest salary in each department
print(df.groupby('Department')['Salary'].max())
# Out:
# Department
# HR       48000
# IT       75000
# Sales    55000
# Name: Salary, dtype: int64

# %%
# count employees in each department
print(df.groupby('Department').size())
# Out:
# Department
# HR       2
# IT       2
# Sales    2
# dtype: int64

# %%
# Display unique department names
print(df['Department'].unique())
# Out:
# <StringArray>
# ['Sales', 'IT', 'HR']
# Length: 3, dtype: str

# %%
# Sort departments by average salary in descending order
print(df.groupby('Department')['Salary'].mean().sort_values(ascending=False))
# Out:
# Department
# IT       72500.0
# Sales    52500.0
# HR       46500.0
# Name: Salary, dtype: float64

# %% [markdown]
# # Merge, Join, Concatenate & Pivot Tables with Examples
# - In real-world projects, your data is often spread across multiple files or tables.
# - Pandas provide powerful functions to combine and summarize data efficiently.
#
# - In this part, you'll learn:
# 1. Merge DataFrames
# 2. Join DataFrames
# 3. Concatenate DataFrames
# 4. Pivot Tables
# 5. CrossTab
# 6. Real-World Use Cases
#
# ## Create Sample DataFrames
# - We'll use these DataFrames throughout the examples.

# %%
import pandas as pd

products = pd.DataFrame({
    'ProductID': [101, 102, 103],
    'Product': ['Laptop', 'Mobile', 'Tablet']
})

sales = pd.DataFrame({
    'ProductID': [101, 102, 103],
    'Sales': [120, 250, 180]
})

# %% [markdown]
# ## Merge DataFrames
# - Use "merge()" to combine DataFrames based on a common column.

# %%
result = pd.merge(products, sales, on='ProductID')
print(result)
# Out:
#    ProductID Product  Sales
# 0        101  Laptop    120
# 1        102  Mobile    250
# 2        103  Tablet    180

# %% [markdown]
# ## Join DataFrames
# - Use "join()" to combine DataFrames using their indexes.

# %%
result = products.join(sales['Sales'])
print(result)
# Out:
#    ProductID Product  Sales
# 0        101  Laptop    120
# 1        102  Mobile    250
# 2        103  Tablet    180

# %% [markdown]
# ## Concatenate DataFrames
# - Use "concat()" to combine DataFrames vertically.

# %%
first = pd.DataFrame({
    'Value': [10, 20]
})
second = pd.DataFrame({
    'Value': [30, 40]
})
result = pd.concat([first, second])
print(result)
# Out:
#    Value
# 0     10
# 1     20
# 0     30
# 1     40

# %% [markdown]
# ## Create a Pivot Table
# - A Pivot Table summarizes data quickly.

# %%
data = pd.DataFrame({
    'Department': ['Sales', 'Sales', 'IT', 'IT'],
    'Salary': [50000, 55000, 70000, 75000]
})
pivot = data.pivot_table(
    values='Salary',
    index='Department',
    aggfunc='mean'
)
print(pivot)
# Out:
#              Salary
# Department
# IT          72500.0
# Sales       52500.0

# %% [markdown]
# ## Create a Crosstab
# - A crosstab counts the frequency of combinations between columns.

# %%
data = pd.DataFrame({
    'Department': ['Sales', 'Sales', 'IT', 'HR'],
    'Shift': ['Morning', 'Evening', 'Morning', 'Evening']
})
print(pd.crosstab(data['Department'], data['Shift']))
# Out:
# Shift       Evening  Morning
# Department
# HR                1        0
# IT                0        1
# Sales             1        1

# %% [markdown]
# **Pro Tip**
# - Remember this rule:
# 1. 'merge()' - Combine using common columns
# 2. 'join()' - Combine using indexes
# 3. 'concat()' - Stack DataFrame vertically
# 4. 'pivot_table()' - Summarize data
# 5. 'crosstab()' - Count combinations

# %%
df1 = pd.DataFrame({'A': [1, 2]})
df2 = pd.DataFrame({'B': [3, 4]})

print(pd.concat([df1, df2]).shape)
# Out:
# (4, 2)

# %% [markdown]
# # DataTime, String Operations & Apply Functions
# - Working with dates, text, and custom logic is a common part of data analysis.
# - Pandas provides powerful built-in functions to handle these tasks efficiently
# - In this part, you'll learn:
# 1. Data & Time Operations
# 2. String Functions
# 3. Apply Functions
# 4. Map Values
# 5. Replace Values
# 6. Export Data
#
# ## Working with Dates
# - Convert a column to DateTime format using **to_datetime()**.

# %%
import pandas as pd

data = {
    'OrderDate': ['2026-08-01', '2026-08-02', '2026-08-03']
}

df = pd.DataFrame(data)

df['OrderDate'] = pd.to_datetime(df['OrderDate'])

df['OrderDate']
# Out:
# 0   2026-08-01
# 1   2026-08-02
# 2   2026-08-03
# Name: OrderDate, dtype: datetime64[us]

# %% [markdown]
# ## Extract Date Components
# - Extract useful information from a date.

# %%
print(df['OrderDate'].dt.year)
print(df['OrderDate'].dt.month)
print(df['OrderDate'].dt.day)
print(df['OrderDate'].dt.day_of_week)
# Out:
# 0    2026
# 1    2026
# 2    2026
# Name: OrderDate, dtype: int32
# 0    8
# 1    8
# 2    8
# Name: OrderDate, dtype: int32
# 0    1
# 1    2
# 2    3
# Name: OrderDate, dtype: int32
# 0    5
# 1    6
# 2    0
# Name: OrderDate, dtype: int32

# %% [markdown]
# ## String Operations
# - Use the **.str** accessor to work with text columns.

# %%
data = {
    'Product': ['Laptop', 'mobile', 'TABLET']
}

df = pd.DataFrame(data)

print(df['Product'].str.upper())
print(df['Product'].str.lower())
# Out:
# 0    LAPTOP
# 1    MOBILE
# 2    TABLET
# Name: Product, dtype: str
# 0    laptop
# 1    mobile
# 2    tablet
# Name: Product, dtype: str

# %% [markdown]
# ## Replace Text
# - Replace specific words or characters.

# %%
data = {
    'Category': ['Old', 'New', 'Old']
}
df = pd.DataFrame(data)

df['Category'] = df['Category'].str.replace('Old', 'Updated')

print(df)
# Out:
#   Category
# 0  Updated
# 1      New
# 2  Updated

# %% [markdown]
# ## Apply Custom Functions
# - Use **apply()** to perform custom operations.

# %%
data = {
    'Price': [100, 250, 400]
}
df = pd.DataFrame(data)

df['Tax'] = df['Price'].apply(lambda price: (price * 0.18)/2)

print(df)
# Out:
#    Price   Tax
# 0    100   9.0
# 1    250  22.5
# 2    400  36.0

# %% [markdown]
# ## Map Values
# - Replace values using a dictionary

# %%
data = {
    'Status': [1, 0, 1, 1, 0]
}
df = pd.DataFrame(data)

status_map = {
    1: 'Active',
    0: 'Inactive'
}

df['Status'] = df['Status'].map(status_map)

print(df)
# Out:
#      Status
# 0    Active
# 1  Inactive
# 2    Active
# 3    Active
# 4  Inactive

# %% [markdown]
# ## Replace Values
# - Replace values directly.

# %%
data = {
    'Priority': ['Low', 'Medium', 'Low', 'High']
}
df = pd.DataFrame(data)
df['Priority'] = df['Priority'].replace('Low', 'Normal')

print(df)
# Out:
#   Priority
# 0   Normal
# 1   Medium
# 2   Normal
# 3     High

# %% [markdown]
# ## Export Data
# - Save a DataFrame to CSV file.

# %%
# df.to_csv('output.csv', index=False)

## Save to an Excel file.
# df.to_excel('output.xlsx', index=False)

# %% [markdown]
# # Matplotlib
# ## Create Your First Charts with Python
# Data is much easier to understand when it's presented visually.
# Matplotlib is the most popular Python library for creating charts and graphs. It helps you transform raw data into meaningfull visual insights.
#
# ## What is Matplotlib?
# Matplotlib is a Python library used for data visualization.
# You can create:
# 1. Line Charts
# 2. Bar Charts
# 3. Pie Charts
# 4. Histograms
# 5. Scatter Plots
#
# These charts help identify trends, patterns and insights from data.
#
# ## Why Learn Matplotlib?
# Matplotlib is widely used in:
# - Data Analysis
# - Business Intelligence
# - Machine Learning
# - Scientific Research
# - Financial Analysis
#
# Visulization helps communicate data more effectively.
#
# ## Create Your First Line Chart

# %%
import matplotlib.pyplot as plt

months = ['Jan', 'Feb', 'Mar', 'Apr', 'May']
sales = [120, 150, 180, 200, 180]

plt.plot(months, sales, label='Sales')

plt.title('Monthly Sales')
plt.xlabel('Month')
plt.ylabel('Sales')

plt.grid(True) # A grid improves chart readability
plt.legend() # A legend identifies the data being displayed
plt.show()

# %%
x = [1, 2, 3]
y = [10, 20]

plt.plot(x, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 4
#       1 x = [1, 2, 3]
#       2 y = [10, 20]
#       3
# ----> 4 plt.plot(x, y)
#
# File ~/DsProjects/dsml-env/lib/python3.12/site-packages/matplotlib/pyplot.py:4043, in plot(scalex, scaley, data, *args, **kwargs)
#    4035 @_copy_docstring_and_deprecators(Axes.plot)
#    4036 def plot(
#    4037     *args: float | ArrayLike | str,
#    (...)   4041     **kwargs,
#    4042 ) -> list[Line2D]:
# -> 4043     return gca().plot(
#    4044         *args,
#    4045         scalex=scalex,
#    4046         scaley=scaley,
#    4047         **({"data": data} if data is not None else {}),
#    4048         **kwargs,
#    4049     )
#
# File ~/DsProjects/dsml-env/lib/python3.12/site-packages/matplotlib/axes/_axes.py:1792, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1549 """
# ...
